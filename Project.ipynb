# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/Project/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction
# Depression is one of the difficult mental illnesses, and is one of the most common in the US. Over 10 million people suffer from depression alone and that number is steadily rising.
