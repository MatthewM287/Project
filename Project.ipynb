# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/Project/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction
# Depression is one of the difficult mental illnesses, and is one of the most common in the US. Over 10 million people suffer from depression alone and that number is steadily rising. Depression is a mental health disorder characterized by persistently depressed mood or loss of interest in activities, causing significant impairment in daily life. Depression can be caused by many things including: faulty mood regulation by the brain, genetic vulnerability, stressful life events, medications, medical problems, and chemical imbalances. It's a dangerous state of mind and the more we understand it the better.

# %% [markdown]
# #Research Questions and Data
# We will analyze the attributes of peoples lives, similarities and differences, and comparing each of their MADRS(MontgomeryЁsberg Depression Rating Scale) scores. The question will be: What set of variables in someone's life makes them most depressed?
# We will use our knowledge of data science (via Python) to download the data and analyze all the variables, searching for which variables influence others the most.
